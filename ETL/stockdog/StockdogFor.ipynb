# %%
import csv
with open('topComList.csv','rb') as csvList:
    num = csvList.readlines()
    csvList.close()
    for item in num:
        broker_id = item[0:4]
        print broker_id
# Out:
# 3658
# 5347
# 6121
# 5903
# 8299
# 6147
# 5530
# 8044
# 5483
# 3691
# 8406
# 3105
# 4162
# 5820
# 4180
# 5371
# 1565
# 5904
# 3529
# 4157
# 8076
# 1795
# 4966
# 3176
# 6244
# 4105
# 5306
# 4123
# 8069
# 5398
# 2035
# 8942
# 3662
# 6146
# 3227
# 4152
# 3260
# 4401
# 3264
# 5263
# 5478
# 3452
# 6279
# 5349
# 5508
# 4128
# 3211
# 6803
# 1785
# 3152
# 5287
# 8936
# 5512
# 3552
# 3558
# 5009
# 3293
# 6188
# 4947
# 8349
# 8255
# 6223
# 1580
# 5356
# 5274
# 9951
# 5425
# 5351
# 3611
# 6023
# 4743
# 6261
# 3520
# 4103
# 4736
# 2926
# 5213
# 8234
# 5489
# 5392
# 6274
# 3490
# 4163
# 8917
# 4198
# 4130
# 4416
# 5490
# 3265
# 4107
# 4911
# 8121
# 8086
# 4549
# 6105
# 3088
# 4120
# 5289
# 3693
# 1256
# 4944
# 8083
# 6016
# 6180
# 8042
# 2729
# 8050
# 5457
# 2330
# 2317
# 2412
# 6505
# 2882
# 2454
# 2881
# 1303
# 1301
# 3008
# 1326
# 2002
# 2308
# 2891
# 3045
# 2886
# 2311
# 4904
# 1216
# 2382
# 2474
# 2207
# 2912
# 2357
# 2105
# 4938
# 2883
# 2892
# 2885
# 1402
# 2880
# 2303
# 3481
# 3474
# ...

# %%
print type(broker_id)
# Out:
# <type 'str'>

# %%
import json,re
import requests
from bs4 import BeautifulSoup
header={
        'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Accept-Encoding':'gzip, deflate, sdch',
        'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
        'Connection':'keep-alive',
        'Cookie':'SDSSESSID=1jsskgcekoej3btte801htkb66; _ga=GA1.3.340433612.1434522404; _gat=1',
        'Host':'www.stockdog.com.tw',
        'Referer':'https://www.stockdog.com.tw/stockdog/index.php?sid=2330&p=8&m=2&sdate=2015-06-24&edate=2015-07-07&submit=%E6%9F%A5%E8%A9%A2',
        'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.130 Safari/537.36'    

}

res = requests.get('https://www.stockdog.com.tw/stockdog/graph.php?Gtype=765e5c0ffc9721c0db42de7061905eef83&level=15&sid=5903%20%E5%8F%B0%E7%A9%8D%E9%9B%BB',headers=header)

#data = json.loads(res.)
print res.text
# Out:
# ﻿
#
#
# <!DOCTYPE HTML>
# <html>
# 	<head>
# 		<meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#
# 		<title>全家(5903) 買賣量能表</title>
#
# 		<script type="text/javascript" src="js/jquery/1.8.2/jquery.min.js"></script>
# 		<script type="text/javascript">
#
#
# 					var chart0;
# 					$(document).ready(function() {
# 						chart0 = new Highcharts.Chart({
# 							chart: {
# 								renderTo: 'container0',
# 								zoomType: 'xy',
# 								events: {
# 									dataGrouping:{enabled:false},
# 									selection: function(event) {
# 										if (event.xAxis) {
#
# 											if (window.parent != null)
# 											{
# 											}
#
#
#
# 										}
# 									},
# 									click: function(e) {
#
#
# 											if (window.parent != null)
# 											{
# 												window.parent.document.getElementById('select_date').value=Highcharts.dateFormat('%Y-%m-%d', e.xAxis[0].value);
# ...

# %%
soup = BeautifulSoup(res.text)
soupforre="".join(soup.select('script')[1].text.split(" "))
soupforre="".join(soupforre.split("	"))
soupforre=soupforre.strip()
print len(soupforre),type(soupforre),#soupforre
x=re.findall(".*(x:.*)",soupforre)
y=re.findall("(y:\d*[^,].*})",soupforre)
# Out:
# 35091 <type 'unicode'>

# %%
fid = open('Stockdog/2330.txt','w')

for i in xrange(238,357):
    #print [x[i],y[i]]
    mounth = int(x[i].split(',',1)[1][0])+1
    day = int(x[i].split(',',1)[1][2])
    over = y[i].split(':')[1]
    rightOver = over.strip('}')
    print mounth,day,rightOver
    fid.write('%d,%d,%s\n'%(mounth,day,rightOver))
fid.close()
# Out:
# 1 7 -8263
# 1 8 9107
# 1 9 -27932
# 1 1 -9765
# 1 1 -9266
# 1 1 -18551
# 1 1 -1858
# 1 1 11979
# 1 1 19230
# 1 2 726
# 1 2 34602
# 1 2 6556
# 1 2 34431
# 1 2 5453
# 1 2 14685
# 1 2 6328
# 1 2 -4132
# 1 3 -10850
# 2 2 -214
# 2 3 1641
# 2 4 7820
# 2 5 -3149
# 2 6 -2199
# 2 9 -6227
# 2 1 -1633
# 2 1 24766
# 2 1 8329
# 2 1 9175
# 2 2 7635
# 2 2 15120
# 2 2 -8638
# 3 2 -10715
# 3 3 -2272
# 3 4 -395
# 3 5 -596
# 3 6 -6680
# 3 9 -30777
# 3 1 -20078
# 3 1 1664
# 3 1 336
# 3 1 496
# 3 1 -8638
# 3 1 11278
# 3 1 27007
# 3 1 5951
# 3 2 1276
# 3 2 250
# 3 2 -4974
# 3 2 -4694
# 3 2 -50964
# 3 2 -41805
# 3 3 -23258
# 3 3 -9211
# 4 1 -3274
# 4 2 7988
# 4 7 -1044
# 4 8 -10898
# 4 9 -4749
# 4 1 9499
# 4 1 -381
# 4 1 -19254
# 4 1 -33328
# 4 1 16618
# 4 1 -20593
# 4 2 -2626
# 4 2 -5406
# 4 2 3229
# 4 2 17358
# 4 2 67397
# 4 2 1228
# 4 2 3933
# 4 2 -5480
# 4 3 -11312
# 5 4 -991
# 5 5 -1610
# 5 6 -306
# 5 7 1344
# 5 8 924
# 5 1 3333
# 5 1 385
# 5 1 2577
# 5 1 -5506
# 5 1 515
# 5 1 -2475
# 5 1 -3582
# ...

# %%
import csv,time
import json,re
import requests
from bs4 import BeautifulSoup
try:
    tot = 0
    with open('ajax.csv','rb') as csvList:
        num = csvList.readlines()
        csvList.close()
        for item in num:
            broker_id = item[0:4]
            header={
                'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
                'Accept-Encoding':'gzip, deflate, sdch',
                'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
                'Connection':'keep-alive',
                'Cookie':'SDSSESSID=1jsskgcekoej3btte801htkb66; _gat=1; _ga=GA1.3.340433612.1434522404',
                'Host':'www.stockdog.com.tw',
                'Referer':'https://www.stockdog.com.tw/stockdog/index.php?sid=2330&p=8&m=2&sdate=2015-06-24&edate=2015-07-07&submit=%E6%9F%A5%E8%A9%A2',
                'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.130 Safari/537.36'  
                
              }
            res = requests.get('https://www.stockdog.com.tw/stockdog/graph.php?Gtype=760b5670f3b26cfc870f137b7186a23716&level=15&sid='+broker_id+'%20%E5%8F%B0%E7%A9%8D%E9%9B%BB',headers=header)
            #print res.text
            soup = BeautifulSoup(res.text)
            soupforre="".join(soup.select('script')[1].text.split(" "))
            soupforre="".join(soupforre.split("	"))
            soupforre=soupforre.strip()
            #print len(soupforre),type(soupforre),#soupforre
            x=re.findall(".*(x:.*)",soupforre)
            y=re.findall("(y:\d*[^,].*})",soupforre)
            fid = open('Stockdog/'+broker_id+'.txt','w')
            for i in xrange(238,357):
                #print [x[i],y[i]]
                mounth = int(x[i].split(',',1)[1][0])+1
                day = int(x[i].split(',',1)[1][2])
                over = y[i].split(':')[1]
                rightOver = over.strip('}')
                #print mounth,day,rightOver
                fid.write('%d,%d,%s\n'%(mounth,day,rightOver))
            tot +=1
            print broker_id+" finished..."
            time.sleep(3)
finally:
    fid.close()
    print tot
# Out:
# 1536 finished...
# 2015 finished...
# 3037 finished...
# 2889 finished...
# 3706 finished...
# 2006 finished...
# 1314 finished...
# 1710 finished...
# 2206 finished...
# 6166 finished...
# 1736 finished...
# 2727 finished...
# 2337 finished...
# 6214 finished...
# 2855 finished...
# 2313 finished...
# 2441 finished...
# 2723 finished...
# 8422 finished...
# 9941 finished...
# 1503 finished...
# 2820 finished...
# 2511 finished...
# 2376 finished...
# 2355 finished...
# 1907 finished...
# 1702 finished...
# 2637 finished...
# 3576 finished...
# 1312 finished...
# 1262 finished...
# 9940 finished...
# 2548 finished...
# 5007 finished...
# 6116 finished...
# 6605 finished...
# 5534 finished...
# 2373 finished...
# 2458 finished...
# 1229 finished...
# 1104 finished...
# 3060 finished...
# 2608 finished...
# 2104 finished...
# 1409 finished...
# 3376 finished...
# 3022 finished...
# 1319 finished...
# 2331 finished...
# 6451 finished...
# 9930 finished...
# 6206 finished...
# 52
