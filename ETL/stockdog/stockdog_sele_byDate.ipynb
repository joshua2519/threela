# %%
import os
from selenium import webdriver
import pyautogui
import random
import time

chromeOptions = webdriver.ChromeOptions()
prefs = {"download.default_directory" : "C:\Temp","download.prompt_for_download": False}
chromeOptions.add_experimental_option("prefs",prefs)
driver = webdriver.Chrome(chrome_options=chromeOptions)
'''
fp = webdriver.FirefoxProfile()
fp.set_preference("browser.download.folderList",2)
fp.set_preference("browser.download.manager.showWhenStarting",False)
fp.set_preference("browser.download.dir", os.getcwd())
fp.set_preference("browser.helperApps.neverAsk.saveToDisk", "application/octet-stream")
driver= webdriver.Firefox(firefox_profile=fp)
'''
driver.implicitly_wait(30)
driver.get("https://www.stockdog.com.tw/")
driver.find_element_by_name("adgh4r23").clear()
driver.find_element_by_name("adgh4r23").send_keys("zb101")
driver.find_element_by_name("fsdfy452d").clear()
driver.find_element_by_name("fsdfy452d").send_keys("123456")
#輸入驗證碼
cat = raw_input()
driver.find_element_by_name("captcha").clear()
driver.find_element_by_name("captcha").send_keys(cat)
driver.find_element_by_css_selector("#next > button.btn.btn-primary").click()

filepath=r"C:/Program Files (x86)/Google/Chrome/Application/43.0.2357.124/"
#設定日期區間
datelist=["2015-05-21","2015-05-20","2015-05-19","2015-05-18","2015-05-15"]

for line in datelist :
    date=line.strip()
    with open('topComList.csv', 'rb') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:            
            sid= row[0]
            name=row[1]
            outfile=(filepath+name+sid+'_買賣日報_細部籌碼_'+date+'_股狗網.csv').decode('utf-8')
            if(os.path.isfile(outfile)):
                print outfile+" exist!"
                continue
            indexUrl='https://www.stockdog.com.tw/stockdog/index.php?sid='+sid+'+'+name+'&p=1&m=2&date='+date    
            driver.get(indexUrl)
            export = driver.find_element_by_id('ZeroClipboard_TableToolsMovie_1')
            time.sleep(3)
            webdriver.ActionChains(driver).move_to_element_with_offset(export,18,18).click().perform()
            time.sleep(3)
            pyautogui.press('tab')
            pyautogui.press('tab')
            pyautogui.press('tab')
            pyautogui.press('enter')
            time.sleep(random.randrange(5,15))
# Out:
# 233
# C:/Program Files (x86)/Google/Chrome/Application/43.0.2357.124/漢微科3658_買賣日報_細部籌碼_2015-05-21_股狗網.csv exist!
# C:/Program Files (x86)/Google/Chrome/Application/43.0.2357.124/漢微科3658_買賣日報_細部籌碼_2015-05-20_股狗網.csv exist!
# C:/Program Files (x86)/Google/Chrome/Application/43.0.2357.124/漢微科3658_買賣日報_細部籌碼_2015-05-19_股狗網.csv exist!
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-1-1515d35ddfa6> in <module>()
#      43     indexUrl='https://www.stockdog.com.tw/stockdog/index.php?sid='+sid+'+'+name+'&p=1&m=2&date='+date
#      44     driver.get(indexUrl)
# ---> 45     export = driver.find_element_by_id('ZeroClipboard_TableToolsMovie_1')
#      46     time.sleep(3)
#      47     webdriver.ActionChains(driver).move_to_element_with_offset(export,18,18).click().perform()
#
# C:\Python27\lib\site-packages\selenium\webdriver\remote\webdriver.pyc in find_element_by_id(self, id_)
#     226             driver.find_element_by_id('foo')
#     227         """
# --> 228         return self.find_element(by=By.ID, value=id_)
#     229
#     230     def find_elements_by_id(self, id_):
#
# C:\Python27\lib\site-packages\selenium\webdriver\remote\webdriver.pyc in find_element(self, by, value)
#     682
#     683         return self.execute(Command.FIND_ELEMENT,
# --> 684                              {'using': by, 'value': value})['value']
#     685
#     686     def find_elements(self, by=By.ID, value=None):
#
# C:\Python27\lib\site-packages\selenium\webdriver\remote\webdriver.pyc in execute(self, driver_command, params)
#     193         response = self.command_executor.execute(driver_command, params)
#     194         if response:
# --> 195             self.error_handler.check_response(response)
#     196             response['value'] = self._unwrap_value(
#     197                 response.get('value', None))
#
# C:\Python27\lib\site-packages\selenium\webdriver\remote\errorhandler.pyc in check_response(self, response)
#     168         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     169             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 170         raise exception_class(message, screen, stacktrace)
#     171
#     172     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element
#   (Session info: chrome=43.0.2357.124)
#   (Driver info: chromedriver=2.15.322448 (52179c1b310fec1797c81ea9a20326839860b7d3),platform=Windows NT 6.1 SP1 x86_64)
